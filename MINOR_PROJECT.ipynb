# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshavardhan-gowdu-v/ML_Minor_Project/blob/main/MINOR_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # for performing mathematical calculations behind ML algorithms
import matplotlib.pyplot as plt # for visualization
import pandas as pd # for handling and cleaning the dataset
import seaborn as sns # for visualization
import sklearn

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/arib168/data/main/50_Startups.csv')
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dataset.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
dataset.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
print('there are ',dataset.shape[0],'rows and ',dataset.shape[1],'columns in the dataset.')
# Out:
# there are  50 rows and  5 columns in the dataset.

# %%
print('There are ',dataset.duplicated().sum(),'duplicate values in the dataset')
# Out:
# There are  0 duplicate values in the dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
# Convert the 'State' column to numerical representation using one-hot encoding
dataset = pd.get_dummies(dataset, columns=['State'], drop_first=True)

# Now calculate the correlation
c = dataset.corr()
c
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit  \
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000
# State_Florida     0.105711        0.010493         0.205685  0.116244
# State_New York    0.039068        0.005145        -0.033670  0.031368
#
#                  State_Florida  State_New York
# R&D Spend             0.105711        0.039068
# Administration        0.010493        0.005145
# Marketing Spend       0.205685       -0.033670
# Profit                0.116244        0.031368
# State_Florida         1.000000       -0.492366
# State_New York       -0.492366        1.000000

# %%
sns.heatmap(c,annot=True,cmap='Reds')
plt.show()

# %%
outliers = ['Profit']
plt.rcParams['figure.figsize'] = [8,8]
sns.boxplot(data=dataset[outliers], orient="v", palette="Set2" , width=0.7) # orient = "v" : vertical boxplot ,
                                                                            # orient = "h" : hotrizontal boxplot
plt.title("Outliers Variable Distribution")
plt.ylabel("Profit Range")
plt.xlabel("Continuous Variable")

plt.show()

# %%
# Replace 'State' with the one-hot encoded state columns in your boxplot.
# Since there are multiple encoded state columns (e.g., State_Florida, State_New York),
# Choose one you are interested in for the x-axis or modify to compare profits across states differently.
# Here's an example using 'State_Florida':

sns.boxplot(x='State_Florida', y='Profit', data=dataset)
plt.show()

# %%
sns.displot(dataset['Profit'],bins=5,kde=True)
plt.show()

# %%
sns.pairplot(dataset)
plt.show()

# %%
# spliting Dataset in Dependent & Independent Variables
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 4].values

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()
X[:, 3] = labelencoder.fit_transform(X[:, 3])
X1 = pd.DataFrame(X)
X1.head()
# Out:
#            0          1          2   3      4
# 0   165349.2   136897.8   471784.1  49  False
# 1   162597.7  151377.59  443898.53  48  False
# 2  153441.51  101145.55  407934.54  47   True
# 3  144372.41  118671.85  383199.62  46  False
# 4  142107.34   91391.77  366168.42  45   True

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,y,train_size=0.7,random_state=0)
x_train
# Out:
# array([[130298.13, 145530.06, 323876.68, 42, True],
#        [119943.24, 156547.42, 256512.92, 35, True],
#        [1000.23, 124153.04, 1903.93, 4, False],
#        [542.05, 51743.15, 0.0, 1, False],
#        [65605.48, 153032.06, 107138.38, 20, False],
#        [114523.61, 122616.84, 261776.23, 34, False],
#        [61994.48, 115641.28, 91131.24, 19, True],
#        [63408.86, 129219.61, 46085.25, 17, False],
#        [78013.11, 121597.55, 264346.06, 33, False],
#        [23640.93, 96189.63, 148001.11, 7, False],
#        [76253.86, 113867.3, 298664.47, 29, False],
#        [15505.73, 127382.3, 35534.17, 6, False],
#        [120542.52, 148718.95, 311613.29, 41, False],
#        [91992.39, 135495.07, 252664.93, 36, False],
#        [64664.71, 139553.16, 137962.62, 24, False],
#        [131876.9, 99814.71, 362861.36, 44, False],
#        [94657.16, 145077.58, 282574.31, 32, False],
#        [28754.33, 118546.05, 172795.67, 9, False],
#        [0.0, 116983.8, 45173.06, 0, False],
# ...

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train,y_train)
print('Model has been trained successfully')
# Out:
# Model has been trained successfully

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 1.00000000e+00,  1.91605677e-16,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00, -1.26629946e-16,  3.02253782e-16, -3.11196028e-16,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.75513508e-16,
#         1.00000000e+00, -3.67439858e-16,  1.00000000e+00])

# %%
testing_data_model_score = model.score(x_test, y_test)
print("Model Score/Performance on Testing data",testing_data_model_score)

training_data_model_score = model.score(x_train, y_train)
print("Model Score/Performance on Training data",training_data_model_score)
# Out:
# Model Score/Performance on Testing data 1.0
# Model Score/Performance on Training data 1.0

# %%
df = pd.DataFrame(data={'Predicted value':y_pred.flatten(),'Actual Value':y_test.flatten()})
df
# Out:
#     Predicted value  Actual Value
# 0      1.000000e+00          True
# 1      1.916057e-16         False
# 2      1.000000e+00          True
# 3      1.000000e+00          True
# 4      1.000000e+00          True
# 5     -1.266299e-16         False
# 6      3.022538e-16         False
# 7     -3.111960e-16         False
# 8      1.000000e+00          True
# 9      1.000000e+00          True
# 10     1.000000e+00          True
# 11     1.755135e-16         False
# 12     1.000000e+00          True
# 13    -3.674399e-16         False
# 14     1.000000e+00          True

# %%
from sklearn.metrics import r2_score
r2Score = r2_score(y_pred, y_test)
print("R2 score of model is :" ,r2Score*100)
# Out:
# R2 score of model is : 100.0

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_pred, y_test)
print("Mean Squarred Error is :" ,mse*100)
# Out:
# Mean Squarred Error is : 1.3969470743495056e-29

# %%
rmse = np.sqrt(mean_squared_error(y_pred, y_test))
print("Root Mean Squarred Error is : ",rmse*100)
# Out:
# Root Mean Squarred Error is :  3.7375755167615084e-14

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_pred,y_test)
print("Mean Absolute Error is :" ,mae)
# Out:
# Mean Absolute Error is : 3.425583187037152e-16
